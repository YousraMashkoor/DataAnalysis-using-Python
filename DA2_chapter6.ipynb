# %% [markdown]
# # **Chapter 06:**
# Statistical Thinking
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/DataAnalysis-with-Python
# Out:
# /content/drive/MyDrive/DataAnalysis-with-Python

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **LECTURE 01:** *Descriptive Statistics*

# %% [markdown]
# Collecting, summarizing, presenting and analyzing data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**Types of Data**

# %% [markdown]
# * **Categorical data:** non-numerical information such as gender, race, religion, marital status etc.
# * **Numerical data:** measurement or count such as height, weight, age, salary, number of children, etc

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Measure of Centeral Tendency**

# %% [markdown]
# #### **1. Mean**

# %% [markdown]
# Mean is an average of all the numbers. The steps required to calculate a mean are:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# mean might be influenced by the outliers.

# %%
x = [1,2,4,5,7,8,200]

sum(x)/6
# Out:
# 37.833333333333336

# %%
np.mean(x)
# Out:
# 4.5

# %% [markdown]
# #### **2. Median**

# %% [markdown]
# Median is the middle value of a sorted list of numbers. The steps required to get a median from a list of numbers are:
#
# ![image.png](data:image/png;base64,...)

# %%
np.median(x)
# Out:
# 4.5

# %% [markdown]
# Note: A median is not influenced by the outliers.

# %% [markdown]
# #### **3. Mode**

# %% [markdown]
# Most repeated value of our data

# %%
[1,2,3,4,4,5,6,2,1,4,9]

# %%
stats.mode(x)
# Out:
# ModeResult(mode=array([1]), count=array([1]))

# %% [markdown]
# ## **LECTURE 02:** *Measure of Variation*

# %% [markdown]
# Variation is always observed in a dataset. This is very unusual to see an entire set of numbers share the exact same values as follows:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When comparing the difference/variability between two datasets, mean and median are not a good option to serve for that purpose. To explain this further, let us look at the two examples below
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * same mean and median which is 300
# * The numbers in the first dataset have a lower variation than the second one despite both of them share the same mean and median.

# %% [markdown]
# ### Why Variability?

# %%
x = [80,85,85,90,95]
x1 = [25,65,70, 125,150]

# %%
np.mean(x)
# Out:
# 87.0

# %%
plt.hist(x)
# Out:
# (array([1., 0., 0., 2., 0., 0., 1., 0., 0., 1.]),
#  array([80. , 81.5, 83. , 84.5, 86. , 87.5, 89. , 90.5, 92. , 93.5, 95. ]),
#  <a list of 10 Patch objects>)

# %%
np.mean(x1)
# Out:
# 87.0

# %%
plt.hist(x1)
# Out:
# (array([1., 0., 0., 2., 0., 0., 0., 0., 1., 1.]),
#  array([ 25. ,  37.5,  50. ,  62.5,  75. ,  87.5, 100. , 112.5, 125. ,
#         137.5, 150. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Variance
# * Standard deviation
# * Skewness
# * Percentiles
# * Ranges

# %% [markdown]
# ## **LECTURE 03:** *Range*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x1 = [80,85,85,90,95]
x2 = [25,65,70, 125,150]

r1 = np.max(x1)-np.min(x1)
print("mean:", np.mean(x1), " range:", r1)
r2 = np.max(x2)-np.min(x2)
print("mean:", np.mean(x2), " range:", r2)
# Out:
# mean: 87.0  range: 15
# mean: 87.0  range: 125

# %% [markdown]
# ### Same Range, Different Distributions:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **LECTURE 04:** *Standard Deviation*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The steps to calculate SD are as follows:
# 1. Calculate the mean of a dataset
# 2. For each number in the dataset, subtract it with the mean
# 3. Square the difference obtained from Step 2
# 4. Sum up the results from Step 3
# 5. Divide the summation from Step 4 by the number of values in the dataset minus one
# 7. Square root the result from Step 5

# %%
Variance
Standard deviation
Skewness
Percentiles
Ranges
