# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv('/content/drive/MyDrive/DataAnalysis-icodeguru-Batch2/Assignments/kiwisaver_sample_wk9.csv')
data
# Out:
#                                         Name  ... Net Assets Share Class
# 0              AMP IL no E Fee NZ Share (RN)  ...              81121.500
# 1         AMP KiwiSaver AMP Income Generator  ...                517.154
# 2            AMP KiwiSaver ANZ Balanced Plus  ...              87999.573
# 3             AMP Prem PSS OnePath NZ Shares  ...               1905.852
# 4   ANZ Default KiwiSaver Scheme Cnsrv(Dflt)  ...             423490.867
# ..                                       ...  ...                    ...
# 71        Simplicity KiwiSaver Balanced Fund  ...               9229.188
# 72    Simplicity KiwiSaver Conservative Fund  ...               2371.001
# 73          Simplicity KiwiSaver Growth Fund  ...              28561.438
# 74         Staples Rodway KiwiSaver Balanced  ...               9131.483
# 75           Staples Rodway KiwiSaver Growth  ...               4573.107
#
# [76 rows x 15 columns]

# %%
data.head()
# Out:
#                                        Name  ... Net Assets Share Class
# 0             AMP IL no E Fee NZ Share (RN)  ...              81121.500
# 1        AMP KiwiSaver AMP Income Generator  ...                517.154
# 2           AMP KiwiSaver ANZ Balanced Plus  ...              87999.573
# 3            AMP Prem PSS OnePath NZ Shares  ...               1905.852
# 4  ANZ Default KiwiSaver Scheme Cnsrv(Dflt)  ...             423490.867
#
# [5 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    76 non-null     object
#  1   Firm Name               76 non-null     object
#  2   Branding Name           76 non-null     object
#  3   Holdings                76 non-null     int64
#  4   Global Category         76 non-null     object
#  5   Morningstar Rating      40 non-null     float64
#  6   Domicile                76 non-null     object
#  7   Fund Legal Structure    76 non-null     object
#  8   Equity Style            76 non-null     object
#  9   Inception Date          76 non-null     object
#  10  Manager Name            33 non-null     object
#  11  Manager Tenure          33 non-null     float64
#  12  Net Assets Date         75 non-null     object
#  13  Net Assets Size         76 non-null     float64
# ...

# %%
data.shape
# Out:
# (76, 15)

# %%
data.columns
# Out:
# Index(['Name', 'Firm Name', 'Branding Name', 'Holdings', 'Global Category',
#        'Morningstar Rating', 'Domicile', 'Fund Legal Structure',
#        'Equity Style', 'Inception Date', 'Manager Name', 'Manager Tenure',
#        'Net Assets Date', 'Net Assets Size', 'Net Assets Share Class'],
#       dtype='object')

# %%
data.describe()
# Out:
#           Holdings  Morningstar Rating  ...  Net Assets Size  Net Assets Share Class
# count    76.000000           40.000000  ...     7.600000e+01            7.600000e+01
# mean    863.592105            3.725000  ...     2.003937e+05            1.202362e+05
# std     737.327538            0.905468  ...     3.982259e+05            2.389356e+05
# min      30.000000            1.000000  ...     6.333030e+02            3.799820e+02
# 25%     150.500000            3.000000  ...     1.062991e+04            6.377949e+03
# 50%     867.500000            4.000000  ...     4.329163e+04            2.597498e+04
# 75%    1538.000000            4.000000  ...     1.364672e+05            8.188030e+04
# max    2458.000000            5.000000  ...     2.468880e+06            1.481328e+06
#
# [8 rows x 5 columns]

# %%
data['Morningstar Rating'].describe()
# Out:
# count    40.000000
# mean      3.725000
# std       0.905468
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       4.000000
# max       5.000000
# Name: Morningstar Rating, dtype: float64

# %%
# Task 2
data['Morningstar Rating'].value_counts()
# Out:
# 4.0    19
# 3.0    11
# 5.0     7
# 2.0     2
# 1.0     1
# Name: Morningstar Rating, dtype: int64

# %%
data['Global Category'].value_counts()
# Out:
# Aggressive Allocation             27
# Allocation                        15
# Cautious Allocation               11
# Moderate Allocation               11
# Australia & New Zealand Equity     7
# Miscellaneous                      3
# New Zealand Equity                 2
# Name: Global Category, dtype: int64

# %%
mean_m=data.groupby('Global Category')['Morningstar Rating'].mean()
mean_m
# Out:
# Global Category
# Aggressive Allocation             3.857143
# Allocation                        3.875000
# Australia & New Zealand Equity    2.800000
# Cautious Allocation               3.833333
# Miscellaneous                          NaN
# Moderate Allocation               4.000000
# New Zealand Equity                3.000000
# Name: Morningstar Rating, dtype: float64

# %%
def remove_nan(row):
   if pd.isnull(row['Morningstar Rating']):
      return mean_m[row['Global Category']]
   else:
        return row['Morningstar Rating']

        # How we return Integer values from user define function     (Type casting of user fn)

# %%
data['Morningstar Rating_new']=data.apply(remove_nan,axis=1)

# %%
data[data['Morningstar Rating_new'].isnull()]
# Out:
#                                      Name  ... Morningstar Rating_new
# 27   Booster KiwiSaver Capital Guaranteed  ...                    NaN
# 67     NZ Funds KiwiSaver Growth Strategy  ...                    NaN
# 68  NZ Funds KiwiSaver Inflation Strategy  ...                    NaN
#
# [3 rows x 16 columns]

# %%
mean=data['Morningstar Rating_new'].mean()
mean
# Out:
# 3.7538975864318322

# %%
def removenan_again(row):
   if pd.isnull(row['Morningstar Rating_new']):
     return mean
   else:
      return row['Morningstar Rating_new']

# %%
data['Morningstar Rating_new']=data.apply(removenan_again,axis=1)

# %%
data[data['Morningstar Rating_new'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Firm Name, Branding Name, Holdings, Global Category, Morningstar Rating, Domicile, Fund Legal Structure, Equity Style, Inception Date, Manager Name, Manager Tenure, Net Assets Date, Net Assets Size, Net Assets Share Class, Morningstar Rating_new]
# Index: []

# %%
# Task 3
data['Equity Style'].value_counts()
# Out:
# Large Growth    33
# Large Blend     28
# Mid Growth      10
# Mid Blend        3
# Mid Value        2
# Name: Equity Style, dtype: int64

# %%
# Large Growth Equity Style is used most and 
# Mid Value Equity Style is used least

# %%
# Task 4
data['Morningstar_name']=data['Morningstar Rating'].map(lambda a: 'Awsome' if a==5 else'Good' if a==4 else 'Average'if a==3 else'bad'if a==2 else 'Awful' )

# %%
data.head()
# Out:
#                                        Name  ... Morningstar_name
# 0             AMP IL no E Fee NZ Share (RN)  ...          Average
# 1        AMP KiwiSaver AMP Income Generator  ...            Awful
# 2           AMP KiwiSaver ANZ Balanced Plus  ...          Average
# 3            AMP Prem PSS OnePath NZ Shares  ...          Average
# 4  ANZ Default KiwiSaver Scheme Cnsrv(Dflt)  ...             Good
#
# [5 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['Name', 'Firm Name', 'Branding Name', 'Holdings', 'Global Category',
#        'Morningstar Rating', 'Domicile', 'Fund Legal Structure',
#        'Equity Style', 'Inception Date', 'Manager Name', 'Manager Tenure',
#        'Net Assets Date', 'Net Assets Size', 'Net Assets Share Class',
#        'Morningstar Rating_new', 'Morningstar_name'],
#       dtype='object')

# %%
# Task 5
data.groupby(['Branding Name','Equity Style'])['Holdings','Net Assets Size'].agg(np.mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                      Holdings  Net Assets Size
# Branding Name       Equity Style
# AMP                 Large Growth  1544.000000     1.466660e+05
#                     Mid Blend      689.000000     8.619230e+02
#                     Mid Growth      92.000000     6.918946e+04
# ANZ                 Large Growth  1543.111111     5.191668e+05
#                     Mid Growth     438.666667     2.460913e+05
# ASB                 Large Blend   1319.500000     1.191800e+06
#                     Large Growth  1222.333333     5.645363e+03
# Aon                 Large Blend    265.000000     1.911613e+04
#                     Mid Growth     384.000000     8.220035e+04
# Bank of New Zealand Large Blend   2456.800000     1.425594e+05
# ...

# %%
# Task 6 
data.pivot_table(values=['Holdings','Net Assets Size'],index=['Branding Name','Equity Style'],aggfunc=np.mean)
# Out:
#                                      Holdings  Net Assets Size
# Branding Name       Equity Style
# AMP                 Large Growth  1544.000000     1.466660e+05
#                     Mid Blend      689.000000     8.619230e+02
#                     Mid Growth      92.000000     6.918946e+04
# ANZ                 Large Growth  1543.111111     5.191668e+05
#                     Mid Growth     438.666667     2.460913e+05
# ASB                 Large Blend   1319.500000     1.191800e+06
#                     Large Growth  1222.333333     5.645363e+03
# Aon                 Large Blend    265.000000     1.911613e+04
#                     Mid Growth     384.000000     8.220035e+04
# Bank of New Zealand Large Blend   2456.800000     1.425594e+05
# Fisher Funds        Large Growth   209.500000     6.073430e+05
# Forsyth Barr        Large Growth   153.000000     1.142776e+04
# Generate            Mid Blend       56.000000     1.074962e+05
# ...

# %%
# Task 7
data.dropna(subset=['Morningstar Rating' , 'Manager Name'],how='all')
# Out:
#                                         Name  ... Morningstar_name
# 0              AMP IL no E Fee NZ Share (RN)  ...          Average
# 2            AMP KiwiSaver ANZ Balanced Plus  ...          Average
# 3             AMP Prem PSS OnePath NZ Shares  ...          Average
# 4   ANZ Default KiwiSaver Scheme Cnsrv(Dflt)  ...             Good
# 5      ANZ Default KiwiSaver Scheme-Balanced  ...          Average
# 6   ANZ Default KiwiSaver Scheme-Balanced Gr  ...          Average
# 7     ANZ Default KiwiSaver Scheme-Cnsrv Bal  ...             Good
# 8        ANZ Default KiwiSaver Scheme-Growth  ...           Awsome
# 9                     ANZ KiwiSaver-Balanced  ...             Good
# 10             ANZ KiwiSaver-Balanced Growth  ...             Good
# 11                ANZ KiwiSaver-Conservative  ...             Good
# 12       ANZ KiwiSaver-Conservative Balanced  ...             Good
# 13                      ANZ KiwiSaver-Growth  ...           Awsome
# ...

# %%
data.groupby()
