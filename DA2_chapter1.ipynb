# %% [markdown]
# # **Chapter 01:**
# Introduction To Pandas
#
# ---

# %% [markdown]
# ![pandas.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![data science1.png](data:image/png;base64,...)

# %% [markdown]
# ![principa-4-types-of-data-analytics.png](data:image/png;base64,...)

# %% [markdown]
# ## **LECTURE 01:** *Inspecting Dataframe*

# %%
# topic 2.1

import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Creating a Dataframe

pd.DataFrame(
    {'names': ["Gumbal", "Darwin", "Anais"], 
     'Age': [12, 10, 5]})
# Out:
#     names  Age
# 0  Gumbal   12
# 1  Darwin   10
# 2   Anais    5

# %%
#Creating series

pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
sales = pd.Series([30, 35, 40], index=['day 1', 'day 2', 'day 3'], name='Product A')
print(sales)
# Out:
# day 1    30
# day 2    35
# day 3    40
# Name: Product A, dtype: int64

# %%
[1,2,3,4]
(1,2,3,4,5)

# %%
sales
# Out:
# day 1    30
# day 2    35
# day 3    40
# Name: Product A, dtype: int64

# %%
sales2 = sales.to_frame()
print(sales2)
# Out:
#        Product A
# day 1         30
# day 2         35
# day 3         40

# %%
#Reading a DataFrame
'''
Product A,Product B,Product C,
30,21,9,
35,34,1,
41,11,11

'''

# %%
cd /content/drive/MyDrive/DataAnalysis-with-Python
# Out:
# /content/drive/MyDrive/DataAnalysis-with-Python

# %%
data = pd.read_csv('titanic.csv')

# %%
ls
# Out:
# airlines_final.csv  Book2.csv  Data2.csv  ride_sharing_new.csv
# Book1.csv           Data1.csv  Data3.csv  titanic.csv

# %%
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ![data-dict.png](data:image/png;base64,...)

# %% [markdown]
# https://www.kaggle.com/c/titanic/data

# %%
# Print the shape of Data1
print(data.shape)
# Out:
# (891, 12)

# %%
# Print the head of the Data1
print(data.head())
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# Print information about Data1
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
# Print a description of Data1
print(data.describe())
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
# ## **LECTURE 02:** *Some Basic Methods*

# %%
# topic 2.2

# Print the top few rows
print(data.head(10))
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
# Print the bottom 5 rows
print(data.tail())
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
# Print the values of Data
print(data.values)
# Out:
# [[1 0 3 ... 7.25 nan 'S']
#  [2 1 1 ... 71.2833 'C85' 'C']
#  [3 1 3 ... 7.925 nan 'S']
#  ...
#  [889 0 3 ... 23.45 nan 'S']
#  [890 1 1 ... 30.0 'C148' 'C']
#  [891 0 3 ... 7.75 nan 'Q']]

# %%
data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
# Count the number of each type
gender = data.Sex.value_counts()
print(gender)

# Get the proportion of gender of each type
gender_per = data.Sex.value_counts(normalize=True)
print(gender_per)

# Count the number of each class number and unsort
unsorted = data.Pclass.value_counts(sort=False)
print(unsorted)

# Get the percentahe of each class
gender_sorted = data.Pclass.value_counts(sort=True, normalize=True)
print(gender_sorted)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %%
# Print the column index of Data
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Print the row index of Data
print(data.index)
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# Sort data by individuals
data.sort_values("Fare", ascending=False)
# Out:
#      PassengerId  Survived  Pclass  ...      Fare        Cabin  Embarked
# 258          259         1       1  ...  512.3292          NaN         C
# 737          738         1       1  ...  512.3292         B101         C
# 679          680         1       1  ...  512.3292  B51 B53 B55         C
# 88            89         1       1  ...  263.0000  C23 C25 C27         S
# 27            28         0       1  ...  263.0000  C23 C25 C27         S
# ..           ...       ...     ...  ...       ...          ...       ...
# 633          634         0       1  ...    0.0000          NaN         S
# 413          414         0       2  ...    0.0000          NaN         S
# 822          823         0       1  ...    0.0000          NaN         S
# 732          733         0       2  ...    0.0000          NaN         S
# 674          675         0       2  ...    0.0000          NaN         S
#
# [891 rows x 12 columns]

# %%
# Sort data by list
#for two values, we have to use list []
sorted = data.sort_values(["Pclass","Fare"], ascending=False)
sorted.head(10)

# %% [markdown]
# ## **LECTURE 03:** *Subsetting Columns*

# %%
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
# topic 2.3

# Select the fare and survived columns
data_com = data[['Fare', 'Survived']]

# Print the head of the result
data_com.head(10)
# Out:
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0
# 5   8.4583         0
# 6  51.8625         0
# 7  21.0750         0
# 8  11.1333         1
# 9  30.0708         1

# %%
# Filter for rows where fare is greater than 70
print(data["Fare"] > 70)

# See the result
data[data["Fare"] > 70]
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
# Filter for rows where Gender is female
females = data[data['Sex']=='female']

# See the result
females
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 8              9         1       3  ...  11.1333   NaN         S
# 9             10         1       2  ...  30.0708   NaN         C
# ..           ...       ...     ...  ...      ...   ...       ...
# 880          881         1       2  ...  26.0000   NaN         S
# 882          883         0       3  ...  10.5167   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
#
# [314 rows x 12 columns]

# %%
# with & we can use two conditions as discussed above
female_sur = data[(data['Sex']=='female') & (data['Survived'] == 1) ]

# See the result
female_sur
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 8              9         1       3  ...  11.1333   NaN         S
# 9             10         1       2  ...  30.0708   NaN         C
# ..           ...       ...     ...  ...      ...   ...       ...
# 874          875         1       2  ...  24.0000   NaN         C
# 875          876         1       3  ...   7.2250   NaN         C
# 879          880         1       1  ...  83.1583   C50         C
# 880          881         1       2  ...  26.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
#
# [233 rows x 12 columns]

# %%
# Add total col as sum of individuals and family_members
data['Family'] = data['SibSp'] + data['Parch']

# See the result
print(data.head())
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Family
# 0            1         0       3  ...   NaN        S       1
# 1            2         1       1  ...   C85        C       1
# 2            3         1       3  ...   NaN        S       0
# 3            4         1       1  ...  C123        S       1
# 4            5         0       3  ...   NaN        S       0
#
# [5 rows x 13 columns]

# %%
data.Family.value_counts()
# Out:
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: Family, dtype: int64

# %%
x = pd.Series([1,2,3,4,5])


y = x
x[0]=2
y
# Out:
# 0    2
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ## **LECTURE 04:** *Summary Statistics*

# %% [markdown]
# What is the average age of the Titanic passengers?

# %%
# topic 2.4

data["Age"].mean()
# Out:
# 29.69911764705882

# %%
x = [1,2,3,4,4,5]
# mean
mean = 1+2+3+4+5/5
# median
# - sort values
# - middle value
median = 3

x = [1,2,3,4,5,6]

# %%
x = pd.Series([1,2,3,4,6])
x.mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# dtype: int64

# %%
x=[1,2,3,4,None,6]
x
# Out:
# [1, 2, 3, 4, None, 6]

# %%
x.mode?

# %% [markdown]
# What is the median age and ticket fare price of the Titanic passengers?

# %%
data[["Age", "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
data[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
# Print the maximum of the date column
print(data[["Age", "Fare"]].max())

# Print the minimum of the date column
print(data[["Age", "Fare"]].min())
# Out:
# Age      80.0000
# Fare    512.3292
# dtype: float64
# Age     0.42
# Fare    0.00
# dtype: float64

# %%
# Similarly The .agg() method allows you to apply your own custom functions to a DataFrame, 
#as well as apply functions to more than one column of a DataFrame at once, 
#making your aggregations super-efficient.

# %%
data[["Age", "Fare"]].agg(["min", "max", "mean", "median"])
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# mean    29.699118   32.204208
# median  28.000000   14.454200

# %% [markdown]
# In order to populate the missing ages I will use the mean age based on the Sex and Pclass

# %%
data[data['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 5              6         0       3  ...   8.4583   NaN         Q
# 17            18         1       2  ...  13.0000   NaN         S
# 19            20         1       3  ...   7.2250   NaN         C
# 26            27         0       3  ...   7.2250   NaN         C
# 28            29         1       3  ...   7.8792   NaN         Q
# ..           ...       ...     ...  ...      ...   ...       ...
# 859          860         0       3  ...   7.2292   NaN         C
# 863          864         0       3  ...  69.5500   NaN         S
# 868          869         0       3  ...   9.5000   NaN         S
# 878          879         0       3  ...   7.8958   NaN         S
# 888          889         0       3  ...  23.4500   NaN         S
#
# [177 rows x 12 columns]

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
mean_age = data['Age'].mean()
def remove_na_ages(row):
    '''
    function to check if the age is null and replace wth the mean from 
    the mean ages dataframe 
    '''
    if pd.isnull(row['Age']):
        return mean_age
    else:
        return row['Age']

# %%
data.apply(remove_na_ages, axis=1)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Length: 891, dtype: float64

# %%
data.apply?

# %%
data['Age_new'] = data.apply(remove_na_ages, axis=1)

# %%
data[data['Age_new'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age_new]
# Index: []

# %%
data['class_name'] = data['Pclass'].map(lambda s: 'Upper Class' if s==1 else 'Middle Class' if s==2 else 'Lower Class')

# %%
data[['class_name', 'Pclass']]
# Out:
#        class_name  Pclass
# 0     Lower Class       3
# 1     Upper Class       1
# 2     Lower Class       3
# 3     Upper Class       1
# 4     Lower Class       3
# ..            ...     ...
# 886  Middle Class       2
# 887   Upper Class       1
# 888   Lower Class       3
# 889   Upper Class       1
# 890   Lower Class       3
#
# [891 rows x 2 columns]

# %% [markdown]
# ## **LECTURE 05:** *Slicing and Indexing*

# %%
a = ['spam', 'egg', 'bacon', 'tomato', 'ham', 'lobster']
# 0 - n-1 (+ve indexing) 
# -1 - -n (-ve indexing)

# %%
a[0]
a[-2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-ae411e5254a8> in <module>()
#       1 a[0]
#       2 a[-2]
# ----> 3 a[0][4]
#
# IndexError: string index out of range

# %%
a[len(a)-1]
# Out:
# 'lobster'

# %%
a[-1]
# Out:
# 'lobster'

# %%
a[len(a)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-836f840eaf9f> in <module>()
# ----> 1 a[len(a)]
#
# IndexError: list index out of range

# %%
len(a)
# Out:
# 6

# %% [markdown]
# ### Slicing

# %%
a = ['spam', 'egg', 'bacon', 'tomato', 'ham', 'lobster']

# %%
a[2:5]
# Out:
# ['bacon', 'tomato', 'ham']

# %%
a[-2:-5]

# how to get same output with positive index?
# 
a[1:4]
# Out:
# []

# %%
a[:4]
# Out:
# ['spam', 'egg', 'bacon', 'tomato']

# %%
a[0:4]
# Out:
# ['spam', 'egg', 'bacon', 'tomato']

# %%
a[2:]
# Out:
# ['bacon', 'tomato', 'ham', 'lobster']

# %%
a[2:len(a)]
# Out:
# ['bacon', 'tomato', 'ham', 'lobster']

# %%
a[:]
# Out:
# ['spam', 'egg', 'bacon', 'tomato', 'ham', 'lobster']

# %% [markdown]
# ###Stride

# %%
a
# Out:
# ['spam', 'egg', 'bacon', 'tomato', 'ham', 'lobster']

# %%
a[0:10:2]
# Out:
# ['spam', 'bacon', 'ham']

# %%
a[6:0:-2]
# Out:
# ['lobster', 'tomato', 'egg']

# %%
a[::-1]
# Out:
# ['lobster', 'ham', 'tomato', 'bacon', 'egg', 'spam']

# %% [markdown]
# ## **LECTURE 06:** *Selection with loc and iloc*

# %% [markdown]
# ### Native accessors

# %%
data.Pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
data['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
data['Pclass'][0]
# Out:
# 3

# %%
data.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.iloc[:,3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data.iloc[:3, 2]
# Out:
# 0    3
# 1    1
# 2    3
# Name: Pclass, dtype: int64

# %%
data[['Age','Pclass']]
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
data.iloc[1:3, 3]
# Out:
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# Name: Name, dtype: object

# %%
data.iloc[[0, 1, 2], 3]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# Name: Name, dtype: object

# %%
data.iloc[-10:]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 881          882         0       3  ...   7.8958   NaN         S
# 882          883         0       3  ...  10.5167   NaN         S
# 883          884         0       2  ...  10.5000   NaN         S
# 884          885         0       3  ...   7.0500   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [10 rows x 12 columns]

# %% [markdown]
# ### Label Based Selection

# %%
data.loc[0, 'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.loc[:, ['Name', 'Fare', 'Sex']]
# Out:
#                                                   Name     Fare     Sex
# 0                              Braund, Mr. Owen Harris   7.2500    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833  female
# 2                               Heikkinen, Miss. Laina   7.9250  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  female
# 4                             Allen, Mr. William Henry   8.0500    male
# ..                                                 ...      ...     ...
# 886                              Montvila, Rev. Juozas  13.0000    male
# 887                       Graham, Miss. Margaret Edith  30.0000  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500  female
# 889                              Behr, Mr. Karl Howell  30.0000    male
# 890                                Dooley, Mr. Patrick   7.7500    male
#
# [891 rows x 3 columns]

# %% [markdown]
# ### Conditional Selection

# %%
data[data.Survived == 1]
# Out:
#      Unnamed: 0  PassengerId  Survived  ...     Fare Cabin Embarked
# 1             1            2         1  ...  71.2833   C85        C
# 2             2            3         1  ...   7.9250   NaN        S
# 3             3            4         1  ...  53.1000  C123        S
# 8             8            9         1  ...  11.1333   NaN        S
# 9             9           10         1  ...  30.0708   NaN        C
# ..          ...          ...       ...  ...      ...   ...      ...
# 875         875          876         1  ...   7.2250   NaN        C
# 879         879          880         1  ...  83.1583   C50        C
# 880         880          881         1  ...  26.0000   NaN        S
# 887         887          888         1  ...  30.0000   B42        S
# 889         889          890         1  ...  30.0000  C148        C
#
# [342 rows x 13 columns]

# %%
data.loc[data.Survived == 1]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 8              9         1       3  ...  11.1333   NaN         S
# 9             10         1       2  ...  30.0708   NaN         C
# ..           ...       ...     ...  ...      ...   ...       ...
# 875          876         1       3  ...   7.2250   NaN         C
# 879          880         1       1  ...  83.1583   C50         C
# 880          881         1       2  ...  26.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 889          890         1       1  ...  30.0000  C148         C
#
# [342 rows x 12 columns]

# %%
data.loc[(data.Survived == 1) & (data.Sex == 'female')]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 8              9         1       3  ...  11.1333   NaN         S
# 9             10         1       2  ...  30.0708   NaN         C
# ..           ...       ...     ...  ...      ...   ...       ...
# 874          875         1       2  ...  24.0000   NaN         C
# 875          876         1       3  ...   7.2250   NaN         C
# 879          880         1       1  ...  83.1583   C50         C
# 880          881         1       2  ...  26.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
#
# [233 rows x 12 columns]

# %%
data.loc[(data.Survived == 1) | (data.Sex == 'female')]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 8              9         1       3  ...  11.1333   NaN         S
# 9             10         1       2  ...  30.0708   NaN         C
# ..           ...       ...     ...  ...      ...   ...       ...
# 882          883         0       3  ...  10.5167   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
#
# [423 rows x 12 columns]

# %%
data.loc[data.Embarked.isin(['S', 'C'])]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 884          885         0       3  ...   7.0500   NaN         S
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
#
# [812 rows x 12 columns]

# %%
data.loc[data.Fare.notnull()]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 1              2         1       1  ...  71.2833          C85         C
# 3              4         1       1  ...  53.1000         C123         S
# 6              7         0       1  ...  51.8625          E46         S
# 10            11         1       3  ...  16.7000           G6         S
# 11            12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 871          872         1       1  ...  52.5542          D35         S
# 872          873         0       1  ...   5.0000  B51 B53 B55         S
# 879          880         1       1  ...  83.1583          C50         C
# 887          888         1       1  ...  30.0000          B42         S
# 889          890         1       1  ...  30.0000         C148         C
#
# [204 rows x 12 columns]

# %% [markdown]
# ## **LECTURE 07:** *Groupby and Pivot Table*

# %%
import numpy as np

# %%
data.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
data.groupby(['Sex','Pclass'])['Age'].mean()
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
data.groupby('Pclass')["Age"].agg([np.min, np.max, np.mean, np.median])
# Out:
#         amin  amax       mean  median
# Pclass
# 1       0.92  80.0  38.233441    37.0
# 2       0.67  70.0  29.877630    29.0
# 3       0.42  74.0  25.140620    24.0

# %%
data.groupby('Pclass')["Age", "Fare"].agg([np.min, np.max, np.mean, np.median])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#          Age                         Fare
#         amin  amax       mean median amin      amax       mean   median
# Pclass
# 1       0.92  80.0  38.233441   37.0  0.0  512.3292  84.154687  60.2875
# 2       0.67  70.0  29.877630   29.0  0.0   73.5000  20.662183  14.2500
# 3       0.42  74.0  25.140620   24.0  0.0   69.5500  13.675550   8.0500

# %% [markdown]
# What is the number of passengers in each of the cabin classes?

# %%
data['Pclass'].value_counts(sort=False)
# Out:
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
#@title Achieve above result with groupby { vertical-output: true, display-mode: "form" }
data.groupby('Pclass').Pclass.count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
#@title What is the mean ticket fare price for each of the sex and cabin class combinations?

data.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
group = data.groupby(['Sex','Pclass'])['Age'].mean()
group
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
mean_ages = data.groupby(['Sex','Pclass'])['Age'].mean()

# %%
mean_ages
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
mean_ages['female', 1]
# Out:
# 34.61176470588235

# %%
mean_ages = data.groupby(['Sex','Pclass'])['Age'].mean()

def remove_na_ages(row):
    '''
    function to check if the age is null and replace wth the mean from 
    the mean ages dataframe 
    '''
    if pd.isnull(row['Age']): #female - 1
        return mean_ages[row['Sex'],row['Pclass']]
    else:
        return row['Age']

# %%
data['Age_new2'] = data.apply(remove_na_ages, axis=1)

# %%
data.head(10)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked   Age_new2
# 0           0            1         0       3  ...   7.2500   NaN         S  22.000000
# 1           1            2         1       1  ...  71.2833   C85         C  38.000000
# 2           2            3         1       3  ...   7.9250   NaN         S  26.000000
# 3           3            4         1       1  ...  53.1000  C123         S  35.000000
# 4           4            5         0       3  ...   8.0500   NaN         S  35.000000
# 5           5            6         0       3  ...   8.4583   NaN         Q  26.507589
# 6           6            7         0       1  ...  51.8625   E46         S  54.000000
# 7           7            8         0       3  ...  21.0750   NaN         S   2.000000
# 8           8            9         1       3  ...  11.1333   NaN         S  27.000000
# 9           9           10         1       2  ...  30.0708   NaN         C  14.000000
#
# [10 rows x 14 columns]

# %%
import numpy as np

# %%
data.pivot_table(values="Age", index="Sex")
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
data.pivot_table(values="Fare", index="Survived")
# Out:
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
pd.pivot_table(data, index = ["Sex","Age"], aggfunc=np.sum)
# Out:
#                   Fare  Parch  PassengerId  Pclass  SibSp  Survived
# Sex    Age
# female 0.75    38.5166      2         1115       6      4         2
#        1.00    26.8750      3          555       6      1         2
#        2.00   259.4750      9         2278      15      9         2
#        3.00    62.6542      3          419       5      4         1
#        4.00   114.1417      6         2258      13      4         5
# ...                ...    ...          ...     ...    ...       ...
# male   70.00   81.5000      1         1419       3      1         0
#        70.50    7.7500      0          117       3      0         0
#        71.00   84.1584      0          591       2      0         0
#        74.00    7.7750      0          852       3      0         0
#        80.00   30.0000      0          631       1      0         1
#
# [145 rows x 6 columns]

# %%
pd.pivot_table(data, index = ["Survived"], aggfunc=np.sum)
# Out:
#                Age      Age_new2        Fare  ...  Pclass  SibSp  Unnamed: 0
# Survived                                      ...
# 0         12985.50  16484.082187  12142.7199  ...    1390    304      244863
# 1          8219.67   9638.828474  16551.2294  ...     667    162      151632
#
# [2 rows x 8 columns]

# %%
pd.pivot_table(data, index=["Survived"], columns=["Sex"], values=["Fare"], aggfunc="mean")
# Out:
#                Fare
# Sex          female       male
# Survived
# 0         23.024385  21.960993
# 1         51.938573  40.821484

# %%
data.groupby(['Survived','Sex'])['Fare'].mean()
# Out:
# Survived  Sex
# 0         female    23.024385
#           male      21.960993
# 1         female    51.938573
#           male      40.821484
# Name: Fare, dtype: float64

# %%
#@title Achieve above result using group by
data.groupby(['Survived','Sex'])['Fare'].mean()

# %%
data.head(10)

# %% [markdown]
# for all the pasangers with age null, find number of females and male pasangers

# %%
data[data['Age'].isnull()].groupby('Sex')['Sex'].count()
# Out:
# Sex
# female     53
# male      124
# Name: Sex, dtype: int64

# %%
pd.pivot_table?

# %%
data.to_csv('new_data2.csv')
